# %% [markdown]
# Link : https://medium.com/@sachinsoni600517/introduction-to-model-quantization-4effc7a17000
#
#
#
# ` What is the quantization`.
#
#
# Model Quantization is a technique used to reduce the size of large neural networks, including large language models (LLMs), by modifying the precision of their weights.
#
#  The process of quantization attempts to reduce the memory size of LLMs while maintaining an acceptable level of performance and accuracy,
#
# `Basics of quantization`
#
# 1. Advantages and disadvantages of quantized models
#
# 2. Find and use already quantized models
#
# 3. Quantization techniques including sample code
#
#
#
#
#
# `How does the quantization shrink the  llm model ?  `
#
#
#
# ![image.png](attachment:image.png)
